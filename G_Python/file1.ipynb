# %%
num1 = 10
num2 = 5
add = num1 + num2
sub = num1 - num2
mul = num1 * num2
div = num1 / num2
print("Addition:", add)
print("Subtraction:", sub)
print("Multiplication:", mul)
print("Division:", div)
# Out:
# Addition: 15
# Subtraction: 5
# Multiplication: 50
# Division: 2.0
